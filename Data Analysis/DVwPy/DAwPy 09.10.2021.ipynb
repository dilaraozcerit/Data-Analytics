# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
df.info() # missing data var...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
df.sex.str.islower().sample(10)
# Out:
# 657    True
# 828    True
# 127    True
# 323    True
# 675    True
# 54     True
# 579    True
# 176    True
# 608    True
# 328    True
# Name: sex, dtype: bool

# %%
df.sex.str.isupper().sum()
# Out:
# 0

# %%
df.sex.str.contains("female")
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: sex, Length: 891, dtype: bool

# %%
df[df.sex == "female"] # cinsiyeti kadın olanları aldık.
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 8           1       3  female  27.0  ...   NaN  Southampton    yes  False
# 9           1       2  female  14.0  ...   NaN    Cherbourg    yes  False
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 880         1       2  female  25.0  ...   NaN  Southampton    yes  False
# 882         0       3  female  22.0  ...   NaN  Southampton     no   True
# 885         0       3  female  39.0  ...   NaN   Queenstown     no  False
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
#
# [314 rows x 15 columns]

# %%
df.sex = df.sex.str.upper()
df.sex
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 886      MALE
# 887    FEMALE
# 888    FEMALE
# 889      MALE
# 890      MALE
# Name: sex, Length: 891, dtype: object

# %%
df = df.replace("male", "MALE")
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    MALE  22.0  ...   NaN  Southampton     no  False
# 1           1       1  FEMALE  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  FEMALE  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  FEMALE  35.0  ...     C  Southampton    yes  False
# 4           0       3    MALE  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    MALE  27.0  ...   NaN  Southampton     no   True
# 887         1       1  FEMALE  19.0  ...     B  Southampton    yes   True
# 888         0       3  FEMALE   NaN  ...   NaN  Southampton     no  False
# 889         1       1    MALE  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    MALE  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
df.sex.apply(lambda x : x.lower() if x == "MALE" else x)
# Out:
# 0        male
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        male
#         ...
# 886      male
# 887    FEMALE
# 888    FEMALE
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
df["class"] = df["class"].str.swapcase()
df["class"]
# Out:
# 0       tHIRD
# 1       fIRST
# 2       tHIRD
# 3       fIRST
# 4       tHIRD
#         ...
# 886    sECOND
# 887     fIRST
# 888     tHIRD
# 889     fIRST
# 890     tHIRD
# Name: class, Length: 891, dtype: object

# %%
# df.age.str.isnumeric #hata verir çünkü age bir str değil.

# %%
df["age"].astype("string").str.isnumeric()  # type'ını stringe çevirdik.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     <NA>
# 889    False
# 890    False
# Name: age, Length: 891, dtype: boolean

# %%
df["age"].apply(str)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     nan
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: object

# %%
df.age.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64>

# %%
df.age = df.age.replace(np.nan, "unk")
df.age.value_counts()   # 177 tane unknown değerimiz var.
# Out:
# unk     177
# 24.0     30
# 22.0     27
# 18.0     26
# 30.0     25
#        ...
# 70.5      1
# 0.42      1
# 66.0      1
# 53.0      1
# 80.0      1
# Name: age, Length: 89, dtype: int64

# %%
df.age = df.age.map({"unk": "UNK"})
df.age.value_counts()
# Out:
# UNK    177
# Name: age, dtype: int64

# %%
df.age = df.age.replace(np.nan, "unk")
df.age.value_counts()
# Out:
# unk    714
# UNK    177
# Name: age, dtype: int64

# %%
df
# Out:
#      survived  pclass     sex  age  ...  deck  embark_town  alive  alone
# 0           0       3    MALE  unk  ...   NaN  Southampton     no  False
# 1           1       1  FEMALE  unk  ...     C    Cherbourg    yes  False
# 2           1       3  FEMALE  unk  ...   NaN  Southampton    yes   True
# 3           1       1  FEMALE  unk  ...     C  Southampton    yes  False
# 4           0       3    MALE  unk  ...   NaN  Southampton     no   True
# ..        ...     ...     ...  ...  ...   ...          ...    ...    ...
# 886         0       2    MALE  unk  ...   NaN  Southampton     no   True
# 887         1       1  FEMALE  unk  ...     B  Southampton    yes   True
# 888         0       3  FEMALE  UNK  ...   NaN  Southampton     no  False
# 889         1       1    MALE  unk  ...     C    Cherbourg    yes   True
# 890         0       3    MALE  unk  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
df.embark_town.str.contains("bourg")
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: embark_town, Length: 891, dtype: object

# %%
df.embark_town.str.endswith("town")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Name: embark_town, Length: 891, dtype: object

# %%
df.embark_town.str.startswith("Ch")
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: embark_town, Length: 891, dtype: object

# %%
df.embark_town.value_counts(dropna=False)
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# NaN              2
# Name: embark_town, dtype: int64

# %%
df.embark_town.fillna(df.embark_town.mode()[0], inplace=True)

# %%
df[df.embark_town.str.startswith("Ch")] # bu sefer oldu.
# Out:
#      survived  pclass     sex  age  ...  deck  embark_town  alive  alone
# 1           1       1  FEMALE  unk  ...     C    Cherbourg    yes  False
# 9           1       2  FEMALE  unk  ...   NaN    Cherbourg    yes  False
# 19          1       3  FEMALE  UNK  ...   NaN    Cherbourg    yes   True
# 26          0       3    MALE  UNK  ...   NaN    Cherbourg     no   True
# 30          0       1    MALE  unk  ...   NaN    Cherbourg     no   True
# ..        ...     ...     ...  ...  ...   ...          ...    ...    ...
# 866         1       2  FEMALE  unk  ...   NaN    Cherbourg    yes  False
# 874         1       2  FEMALE  unk  ...   NaN    Cherbourg    yes  False
# 875         1       3  FEMALE  unk  ...   NaN    Cherbourg    yes   True
# 879         1       1  FEMALE  unk  ...     C    Cherbourg    yes  False
# 889         1       1    MALE  unk  ...     C    Cherbourg    yes   True
#
# [168 rows x 15 columns]

# %%
# df[df.age.astype("string").str.startswith("2")]

# %%
df.age.astype("string").str.find("unk")
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 886     0
# 887     0
# 888    -1
# 889     0
# 890     0
# Name: age, Length: 891, dtype: Int64

# %%
df.embark_town.str.findall("Queenstwon")
# Out:
# 0      []
# 1      []
# 2      []
# 3      []
# 4      []
#        ..
# 886    []
# 887    []
# 888    []
# 889    []
# 890    []
# Name: embark_town, Length: 891, dtype: object

# %%
df.embark_town.str.find("Queenstwon")
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 886   -1
# 887   -1
# 888   -1
# 889   -1
# 890   -1
# Name: embark_town, Length: 891, dtype: int64

# %% [markdown]
# **DATETIME**

# %%
df = sns.load_dataset("flights")

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df.year = pd.to_datetime(df.year) # datetime object'e dönüştürdük.

# %%
df.year
# Out:
# 0     1970-01-01 00:00:00.000001949
# 1     1970-01-01 00:00:00.000001949
# 2     1970-01-01 00:00:00.000001949
# 3     1970-01-01 00:00:00.000001949
# 4     1970-01-01 00:00:00.000001949
#                    ...
# 139   1970-01-01 00:00:00.000001960
# 140   1970-01-01 00:00:00.000001960
# 141   1970-01-01 00:00:00.000001960
# 142   1970-01-01 00:00:00.000001960
# 143   1970-01-01 00:00:00.000001960
# Name: year, Length: 144, dtype: datetime64[ns]

# %%
from datetime import datetime

# %%
df.year.dt.dayofweek
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 139    3
# 140    3
# 141    3
# 142    3
# 143    3
# Name: year, Length: 144, dtype: int64

# %%
df.year.dt.year
# Out:
# 0      1970
# 1      1970
# 2      1970
# 3      1970
# 4      1970
#        ...
# 139    1970
# 140    1970
# 141    1970
# 142    1970
# 143    1970
# Name: year, Length: 144, dtype: int64

# %%
df.year.unique()
# Out:
# array(['1970-01-01T00:00:00.000001949', '1970-01-01T00:00:00.000001950',
#        '1970-01-01T00:00:00.000001951', '1970-01-01T00:00:00.000001952',
#        '1970-01-01T00:00:00.000001953', '1970-01-01T00:00:00.000001954',
#        '1970-01-01T00:00:00.000001955', '1970-01-01T00:00:00.000001956',
#        '1970-01-01T00:00:00.000001957', '1970-01-01T00:00:00.000001958',
#        '1970-01-01T00:00:00.000001959', '1970-01-01T00:00:00.000001960'],
#       dtype='datetime64[ns]')

# %%
df.year = pd.to_datetime(df.year, format="%Y", errors="ignore")
df.year
# Out:
# 0     1949-01-01
# 1     1949-01-01
# 2     1949-01-01
# 3     1949-01-01
# 4     1949-01-01
#          ...
# 139   1960-01-01
# 140   1960-01-01
# 141   1960-01-01
# 142   1960-01-01
# 143   1960-01-01
# Name: year, Length: 144, dtype: datetime64[ns]

# %%
current_date = datetime.now()
current_date
# Out:
# datetime.datetime(2021, 10, 9, 9, 43, 44, 188574)

# %%
current_date.month
# Out:
# 10

# %%
current_date.now()
# Out:
# datetime.datetime(2021, 10, 9, 9, 44, 36, 238979)

# %%
current_date.today()
# Out:
# datetime.datetime(2021, 10, 9, 9, 44, 44, 438695)

# %%
current_date.strftime(("%d" + " " + "%B" + " " +"%Y"))
# Out:
# '09 October 2021'

# %%
date1 = current_date.strftime("%d %B %Y")
date1
# Out:
# '09 October 2021'

# %%
datetime.strptime(date, "%d %B %Y")
# Out:
# datetime.datetime(2021, 10, 9, 0, 0)

# %%
datetime.strptime(date1, "%d %B %Y")
# Out:
# datetime.datetime(2021, 10, 9, 0, 0)

# %%
from datetime import timedelta

# %%
date
# Out:
# '09 October 2021'

# %%
current_date.now()+timedelta(weeks = 2)
# Out:
# datetime.datetime(2021, 10, 23, 10, 10, 47, 67217)

# %%
current_date+timedelta(weeks = 2)
# Out:
# datetime.datetime(2021, 10, 23, 9, 43, 44, 188574)

# %%
current_date.today()-timedelta(days=3)
# Out:
# datetime.datetime(2021, 10, 6, 10, 12, 48, 905664)

# %%
(current_date.today()-timedelta(days=3)).strftime("%d %B %Y")
# Out:
# '06 October 2021'

# %% [markdown]
# **DATA INPUT OUTPUT**

# %%
df = pd.read_csv("example.csv", skiprows=1)
df
# Out:
#     0   1   2   3
# 0   4   5   6   7
# 1   8   9  10  11
# 2  12  13  14  15

# %%
df = pd.read_csv("example.csv", skiprows=2)
df
# Out:
#     4   5   6   7
# 0   8   9  10  11
# 1  12  13  14  15

# %%
titanic = pd.read_csv("titanic_train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
titanic = pd.read_csv("titanic_train.csv", sep= "/") # default olarak ',' vardır.
titanic
# Out:
#                                                    PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A                                         5 21171,7.25,,S
# 2,1,1,"Cumings, Mrs. John Bradley (Florence Bri...                                                NaN
# 3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,STON                                O2. 3101282,7.925,,S
# 4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May P...                                                NaN
# 5,0,3,"Allen, Mr. William Henry",male,35,0,0,37...                                                NaN
# ...                                                                                               ...
# 887,0,2,"Montvila, Rev. Juozas",male,27,0,0,211...                                                NaN
# 888,1,1,"Graham, Miss. Margaret Edith",female,1...                                                NaN
# ...

# %%
df
# Out:
#     4   5   6   7
# 0   8   9  10  11
# 1  12  13  14  15

# %%
df.to_csv("example")

# %%
df.to_excel("excel1.xlsx", sheet_name= "sh1", index=False)
df
# Out:
#     4   5   6   7
# 0   8   9  10  11
# 1  12  13  14  15

# %% [markdown]
# **SQL**

# %%
pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
temp_db = create_engine("sqlite:///:memory:")

# %%
temp_db.table_names()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# []

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/World_population')

# %%
tables
# Out:
# [        World population (millions, UN estimates)[14]  ...
#                                                      #  ...                                            2030[A]
#  0                                                   1  ...                                               1416
#  1                                                   2  ...                                               1528
#  2                                                   3  ...                                                356
#  3                                                   4  ...                                                295
#  4                                                   5  ...                                                245
#  5                                                   6  ...                                                228
#  6                                                   7  ...                                                263
# ...

# %%
pop = tables[5]
pop
# Out:
#    Rank      Country  Population  Area(km2)  Density(pop/km2)
# 0     1    Singapore     5704000        710              8033
# 1     2   Bangladesh   171490000     143998              1191
# 2     3      Lebanon     6856000      10452               656
# 3     4       Taiwan    23604000      36193               652
# 4     5  South Korea    51781000      99538               520
# 5     6       Rwanda    12374000      26338               470
# 6     7        Haiti    11578000      27065               428
# 7     8  Netherlands    17640000      41526               425
# 8     9       Israel     9410000      22072               426
# 9    10        India  1382840000    3287240               421

# %%
pop.to_sql(name="populations", con=temp_db)

# %%
temp_db.table_names()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# ['populations']

# %%
pd.read_sql(sql = "populations", con= temp_db)
# Out:
#    index  Rank      Country  Population  Area(km2)  Density(pop/km2)
# 0      0     1    Singapore     5704000        710              8033
# 1      1     2   Bangladesh   171490000     143998              1191
# 2      2     3      Lebanon     6856000      10452               656
# 3      3     4       Taiwan    23604000      36193               652
# 4      4     5  South Korea    51781000      99538               520
# 5      5     6       Rwanda    12374000      26338               470
# 6      6     7        Haiti    11578000      27065               428
# 7      7     8  Netherlands    17640000      41526               425
# 8      8     9       Israel     9410000      22072               426
# 9      9    10        India  1382840000    3287240               421

# %%
pd.read_sql_query(sql="select Counrty, Population from populations", con= temp_db)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1789                     self.dialect.do_execute_no_params(
# -> 1790                         cursor, statement, context
#    1791                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute_no_params(self, cursor, statement, context)
#     719     def do_execute_no_params(self, cursor, statement, context=None):
# --> 720         cursor.execute(statement)
#     721
#
# OperationalError: no such column: Counrty
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-106-5e12506e4e8a> in <module>()
# ...
