# %%
# Basic Libraries
import pandas as pd
import numpy as np
# Libraries for visualizaton
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
sns.catplot(x= "pclass", y= "survived", data = titanic, kind="bar");

# %%
sns.catplot(x= "pclass", y= "survived", data = titanic, kind="bar", estimator=np.count_nonzero);

# %%
sns.catplot(x= "pclass", y= "survived", data = titanic, kind="bar", estimator=np.sum);

# %%
sns.catplot(x= "pclass", y= "survived", data = titanic, kind="bar", estimator=np.sum, hue= "sex");

# %%
sns.catplot(x= "pclass", y= "survived", data = titanic, kind="bar", estimator=np.sum, hue= "sex", col="alone", row= "embarked");

# %%
sns.catplot(x= "pclass", y= "survived", data = titanic, kind="bar", estimator=np.sum, hue= "sex", col="sex");

# %%
tips= sns.load_dataset("tips")
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "box");

# %%
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "box", hue = "smoker");

# %%
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "violin", hue = "smoker");

# %%
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "swarm", hue = "smoker");

# %%
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "bar", estimator = np.count_nonzero, hue = "smoker");

# %% [markdown]
# **Joinplot**

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind="hex")

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind="kde")

# %% [markdown]
# **Pairplot**

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = "sex");

# %%
sns.pairplot(tips, hue = "sex", palette = "viridis", corner=True);

# %%
sns.pairplot(tips, hue = "sex", palette = "viridis", corner=True, diag_kind= 'hist'); # distribution yerine hist getirir.

# %% [markdown]
# **PairGrid**

# %%
g=sns.PairGrid(tips)
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, color ="r");

# %%
g = sns.PairGrid(tips, hue="sex", palette="viridis")
g = g.map_upper(sns.scatterplot, linewidths=1, edgecolor="w", s=40)
g = g.map_diag(sns.distplot)
g = g.map_lower(sns.kdeplot)
g = g.add_legend()

# %%
a = sns.pairplot(tips)
a.map_lower(sns.kdeplot, color='purple')
a.map_upper(sns.kdeplot, color='g');

# %% [markdown]
# **Facetgrid**

# %%
g = sns.FacetGrid(data = tips, col="time", row="smoker")
g = g.map(plt.hist, "total_bill")

# %%
g = sns.FacetGrid(data = tips, col="time", row="smoker")
g = g.map(plt.scatter, "total_bill", "tip")

# %% [markdown]
# **Heatmap**

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.heatmap(data=tips.corr());

# %%
sns.heatmap(data=tips.corr(), annot = True);

# %%
sns.heatmap(data=tips.corr(),cmap='viridis',annot=True)

# %%
sns.heatmap(data=tips.corr(),cmap='viridis',annot=True, center=1) # renk spektrumu oluşturuyor.

# %%
sns.heatmap(data=tips.corr(),cmap='viridis',annot=True, center=0.5)

# %%
iris = sns.load_dataset("iris")
species = iris.pop("species")
sns.clustermap(iris);

# %% [markdown]
# ---

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1    Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2    Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3    Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4    Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
# ..      ...        ...             ...  ...                ...          ...     ...
# 339  Gentoo     Biscoe             NaN  ...                NaN          NaN     NaN
# 340  Gentoo     Biscoe            46.8  ...              215.0       4850.0  Female
# 341  Gentoo     Biscoe            50.4  ...              222.0       5750.0    Male
# 342  Gentoo     Biscoe            45.2  ...              212.0       5200.0  Female
# ...

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
sns.heatmap(penguins.isnull())

# %%
sns.catplot(x = "species", y = "bill_length_mm", data = penguins)

# %%
sns.catplot(x = "species", y = "bill_length_mm", data = penguins, kind = "bar", hue = "sex")

# %%
sns.catplot(x = "species", y = "bill_length_mm", data = penguins, kind = "bar", hue = "sex", col = "island") # we categorized by island names.

# %%
sns.catplot(x = "species", y = "body_mass_g", data = penguins, kind = "bar", hue = "sex", col = "island")

# %%
sns.catplot(x = "species", y = "body_mass_g", data = penguins, kind = "box", hue = "sex", col = "island")

# %% [markdown]
# Jointplot

# %%
sns.jointplot(x  = "flipper_length_mm", y = "body_mass_g", data = penguins);
# kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
sns.jointplot(x='flipper_length_mm',y='body_mass_g',data=penguins, kind="reg")

# %%
sns.jointplot(x='flipper_length_mm',y='body_mass_g',data=penguins, hue="species")
